# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create some LogNormal data

# %%
#create the data
#ok so some additional text is added
# This another line of code added.

np.random.seed(43)
data = np.random.lognormal(0.7,1.5,1000)
mean = np.mean(data)
std = np.std(data)
usl = 100

#Calculate the CPk
lsl = 0
cpu = (usl - mean) / (3 * std)
cpl = (mean - lsl) / (3 * std)
cpk = min(cpu,cpl)

sig3 = (mean + (3*std))
sig3b = (mean - (3*std))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(data,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')
plt.axvline(usl,color='r',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(mean,color='black',linestyle='--')
plt.text(mean+1,68,'Mean',rotation=90)
plt.text(usl+1,65,'USL = 100',rotation=90)
plt.text(sig3+1,65,'3 Sigma',rotation=90)
plt.text(lsl+1,65,'LSL = 0',rotation=90)

plt.title(f'Transforming Lognormal Data std = {std}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# Results
#  Cpl = 0.16
#  Cpu = 2.53
#  CPk = 0.16

# %% [markdown]
# ## Transform Data Exp of fraction ( X ** 1/2 )

# %%
#Transform data unit nelow 1.
t6 = (data ** (1/2))
mn = (np.mean(t6))
ul = (100 ** (1/2))
std1 = np.std(t6)

#Caculate the CPk
lsl = 0
cpu = (ul - mn) / (3 * std1)
cpl = (mn - lsl) / (3 * std1)
cpk = min(cpu,cpl)

sig3 = (mn + (3*std1))
sig3b = (mn - (3*std1))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(t6,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(ul,color='r',linestyle='--')
plt.axvline(mn,color='black',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')

plt.text(mn,50,'Mean',rotation=90)
plt.text(ul,50,'USL = 100',rotation=90)
plt.text(sig3,50,'3 Sigma',rotation=90)
plt.text(lsl,50,'LSL = 0',rotation=90)
plt.title(f'Transforming Lognormal Data std = {std1}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# Results
#  Cpl = 0.41
#  Cpu = 1.77
#  CPk = 0.41

# %% [markdown]
# ## Transform Data Exp of fraction ( X ** 1/3 )

# %%
#Create data
t6 = (data ** (1/3))
mn = np.mean(t6)
ul = (100 ** (1/3))
std1 = np.std(t6)

#Caculate the CPk
lsl = 0
cpu = (ul - mn) / (3 * std1)
cpl = (mn - lsl) / (3 * std1)
cpk = min(cpu,cpl)

sig3 = (mn + (3*std1))
sig3b = (mn - (3*std1))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(t6,bins=50,kde=True)

plt.axvline(ul,color='r',linestyle='--')
plt.axvline(mn,color='black',linestyle='--')
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')

plt.text(mn,50,'Mean',rotation=90)
plt.text(ul,50,'USL = 100',rotation=90)
plt.text(sig3,50,'3 Sigma',rotation=90)
plt.text(lsl,50,'LSL = 0',rotation=90)
plt.title(f'Lognormal Data std = {std1}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# Results
#  Cpl = 0.64
#  Cpu = 1.45
#  CPk = 0.64

# %% [markdown]
# ## Transform Data Exp of fraction ( X ** 1/4 )

# %%
#Create data
t6 = (data ** (1/4))
mn = np.mean(t6)
ul = (100 ** (1/4))
std1 = np.std(t6)

#Caculate the CPk
lsl = 0
cpu = (ul - mn) / (3 * std1)
cpl = (mn - lsl) / (3 * std1)
cpk = min(cpu,cpl)

sig3 = (mn + (3*std1))
sig3b = (mn - (3*std1))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(t6,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(ul,color='r',linestyle='--')
plt.axvline(mn,color='black',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')

plt.text(mn,50,'Mean',rotation=90)
plt.text(ul,50,'USL = 100',rotation=90)
plt.text(sig3,50,'3 Sigma',rotation=90)
plt.text(lsl,50,'LSL = 0',rotation=90)
plt.title(f'Lognormal Data std = {std1}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# Results
#  Cpl = 0.88
#  Cpu = 1.29
#  CPk = 0.88

# %% [markdown]
# ## Transform Data Exp of fraction ( X ** 1/5 )

# %%
#Create data
t6 = (data ** (1/5))
mn = np.mean(t6)
ul = (100 ** (1/5))
std1 = np.std(t6)

#Caculate the CPk
lsl = 0
cpu = (ul - mn) / (3 * std1)
cpl = (mn - lsl) / (3 * std1)
cpk = min(cpu,cpl)

sig3 = (mn + (3*std1))
sig3b = (mn - (3*std1))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(t6,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(ul,color='r',linestyle='--')
plt.axvline(mn,color='black',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')

plt.text(mn,50,'Mean',rotation=90)
plt.text(ul,50,'USL = 100',rotation=90)
plt.text(sig3,50,'3 Sigma',rotation=90)
plt.text(lsl,50,'LSL = 0',rotation=90)
plt.title(f'Lognormal Data std = {std1}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# Results
#  Cpl = 1.11
#  Cpu = 1.2
#  CPk = 1.11

# %% [markdown]
# ## Log Transformation Using Log Function

# %%
#Create data
t6 = np.log(data)
mn = np.mean(t6)
ul = np.log(100)
std1 = np.std(t6)

#Caculate the CPk
lsl = np.log(0.0001)
cpu = (ul - mn) / (3 * std1)
cpl = (mn - lsl) / (3 * std1)
cpk = min(cpu,cpl)

sig3 = (mn + (3*std1))
sig3b = (mn - (3*std1))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(t6,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(ul,color='r',linestyle='--')
plt.axvline(mn,color='black',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')

plt.text(mn,50,'Mean',rotation=90)
plt.text(ul,50,'USL = 100',rotation=90)
plt.text(sig3,50,'3 Sigma',rotation=90)
plt.text(lsl,50,'LSL = 0',rotation=90)
plt.title(f'Lognormal Data std = {std1}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# Results
#  Cpl = 2.23
#  Cpu = 0.88
#  CPk = 0.88

# %% [markdown]
# ## Create some Exponential Data

# %%
#create the data
np.random.seed(43)
data = np.random.exponential(scale=7,size=1000)
mean = np.mean(data)
std = np.std(data)
usl = 100

#Calculate the CPk
lsl = 0
cpu = (usl - mean) / (3 * std)
cpl = (mean - lsl) / (3 * std)
cpk = min(cpu,cpl)

sig3 = (mean + (3*std))
sig3b = (mean - (3*std))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(data,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')
plt.axvline(usl,color='r',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(mean,color='black',linestyle='--')
plt.text(mean+1,68,'Mean',rotation=90)
plt.text(usl+1,65,'USL = 100',rotation=90)
plt.text(sig3+1,65,'3 Sigma',rotation=90)
plt.text(lsl+1,65,'LSL = 0',rotation=90)

plt.title(f'Transforming Lognormal Data std = {std}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# Results
#  Cpl = 0.33
#  Cpu = 4.18
#  CPk = 0.33

# %% [markdown]
# ## Transform The Data Exponential (data ** 1/4)

# %%
#Create data
t6 = (data ** (1/4))
mn = np.mean(t6)
ul = (100 ** (1/4))
std1 = np.std(t6)

#Caculate the CPk
lsl = 0
cpu = (ul - mn) / (3 * std1)
cpl = (mn - lsl) / (3 * std1)
cpk = min(cpu,cpl)

sig3 = (mn + (3*std1))
sig3b = (mn - (3*std1))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(t6,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(ul,color='r',linestyle='--')
plt.axvline(mn,color='black',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')

plt.text(mn,45,'Mean',rotation=90)
plt.text(ul,45,'USL = 100',rotation=90)
plt.text(sig3,45,'3 Sigma',rotation=90)
plt.text(lsl,45,'LSL = 0',rotation=90)
plt.title(f'Lognormal Data std = {std1}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# Results
#  Cpl = 1.19
#  Cpu = 1.34
#  CPk = 1.19

# %%
#create the data
np.random.seed(43)
data = (-1*np.random.lognormal(3,0.5,10000)+280)
mean = np.mean(data)
std = np.std(data)
usl = 280

#Calculate the CPk
lsl = 180
cpu = (usl - mean) / (3 * std)
cpl = (mean - lsl) / (3 * std)
cpk = min(cpu,cpl)

sig3 = (mean + (3*std))
sig3b = (mean - (3*std))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(data,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')
plt.axvline(usl,color='r',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(mean,color='black',linestyle='--')
plt.text(mean+1,68,'Mean',rotation=90)
plt.text(usl+1,65,'USL = 330',rotation=90)
plt.text(sig3+1,65,'3 Sigma',rotation=90)
plt.text(lsl+1,65,'LSL = 180',rotation=90)

plt.title(f'Transforming Lognormal Data std = {std}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# Results
#  Cpl = 2.13
#  Cpu = 0.63
#  CPk = 0.63

# %% [markdown]
# ## Must Reflect the data for negative distributions
# ## (mirror the negative distribution to positive distribution)
# ## formula (MAX(data) + 1 - Data)

# %%
#Data Must be refected before normalized.
#REFLECT THE DATA - (MAX + 1 - Data)
data_ref = max(data) + 1 - data

mean = np.mean(data_ref)
std = np.std(data_ref)
usl = max(data) + 1 - 280

#Calculate the CPk
lsl = max(data) + 1 - 180
cpu = (usl - mean) / (3 * std)
cpl = (mean - lsl) / (3 * std)
cpk = min(cpu,cpl)

sig3 = (mean + (3*std))
sig3b = (mean - (3*std))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(data_ref,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')
plt.axvline(usl,color='r',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(mean,color='black',linestyle='--')
plt.text(mean+1,68,'Mean',rotation=90)
plt.text(usl+1,65,'USL = 280',rotation=90)
plt.text(sig3+1,65,'3 Sigma',rotation=90)
plt.text(lsl+1,65,'LSL = 180',rotation=90)

plt.title(f'Transforming Lognormal Data std = {std}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# Results
#  Cpl = -2.13
#  Cpu = -0.63
#  CPk = -2.13

# %%
# NOW GET THE SQRT -330 is the hiest value - this case USL.
data_ref = np.sqrt(max(data) + 1 - data)

mean = np.mean(data_ref)
std = np.std(data_ref)
usl = np.sqrt(max(data) + 1 - 280)


#Calculate the CPk
lsl = np.sqrt(max(data) + 1 - 180)
cpu = (usl - mean) / (3 * std)
cpl = (mean - lsl) / (3 * std)
cpk = min(cpu,cpl)

sig3 = (mean + (3*std))
sig3b = (mean - (3*std))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(data_ref,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')
plt.axvline(usl,color='r',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(mean,color='black',linestyle='--')
plt.text(mean,68,'Mean',rotation=90)
plt.text(usl,65,'USL = 330',rotation=90)
plt.text(sig3,65,'3 Sigma',rotation=90)
plt.text(lsl,65,'LSL = 180',rotation=90)

plt.title(f'Transforming Lognormal Data std = {std}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
usl
# Out:
# Results
#  Cpl = -1.48
#  Cpu = nan
#  CPk = nan
# C:\Users\andyt\AppData\Local\Temp\ipykernel_16856\880836888.py:6: RuntimeWarning: invalid value encountered in sqrt
#   usl = np.sqrt(max(data) + 1 - 280)
# nan
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# NOW GET THE SQRT (adjust the 1/3)
data_ref = (max(data) + 1 - data) ** (1/3)

mean = np.mean(data_ref)
std = np.std(data_ref)

usl = ((max(data) + 1 - 280)**(1/3))
lsl = ((max(data) + 55 - 180)**(1/3))

#Calculate the CPk
cpu = (usl - mean) / (3 * std)
cpl = (mean - lsl) / (3 * std)
cpk = min(cpu,cpl)

sig3 = (mean + (3*std))
sig3b = (mean - (3*std))

#start drawing graph
sns.set_theme('paper')
plt.figure(figsize=(10,8))
sns.histplot(data_ref,bins=50,kde=True)
plt.axvline(sig3,color='g',linestyle='--')
plt.axvline(sig3b,color='g',linestyle='--')
plt.axvline(usl,color='r',linestyle='--')
plt.axvline(lsl,color='r',linestyle='--')
plt.axvline(mean,color='black',linestyle='--')
plt.text(mean,68,'Mean',rotation=90)
plt.text(usl,65,'USL = 280',rotation=90)
plt.text(sig3,65,'3 Sigma',rotation=90)
plt.text(lsl,65,'LSL = 180',rotation=90)

plt.title(f'Transforming Lognormal Data std = {std}')

print(f'Results \n Cpl = {round(cpl,2)} \n Cpu = {round(cpu,2)} \n CPk = {round(cpk,2)}')
# Out:
# C:\Users\andyt\AppData\Local\Temp\ipykernel_16856\173012469.py:7: RuntimeWarning: invalid value encountered in scalar power
#   usl = ((max(data) + 1 - 280)**(1/3))
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# Results
#  Cpl = -1.78
#  Cpu = nan
#  CPk = nan

# %% [markdown]
# ## Reflection data transformation, Limits based on a pivet point.
# * Pivet point normally the max Value of the data.
# * min/max specifications are based on the same scale.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate left-skewed data using Beta distribution
np.random.seed(42)
data = np.random.beta(2, 5, size=1000) * 100  # Scale to [0, 100]
USL = 90  # Upper Specification Limit
LSL = 30  # Lower Specification Limit

# Step 1: Reflection around the maximum value
pivot = max(data)
reflected_data = pivot - data

# Step 2: Adjust specification limits
USL_new = pivot - LSL
LSL_new = pivot - USL

# Step 3: Calculate statistics for reflected data
mean_reflected = np.mean(reflected_data)
std_dev_reflected = np.std(reflected_data)

# Step 4: Calculate CpK for the reflected data
cpk_upper = (USL_new - mean_reflected) / (3 * std_dev_reflected)
cpk_lower = (mean_reflected - LSL_new) / (3 * std_dev_reflected)
cpk = min(cpk_upper, cpk_lower)

# Visualize the original and reflected data
plt.figure(figsize=(12, 6))

# Original data
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(USL, color='red', linestyle='--', label='USL')
plt.axvline(LSL, color='green', linestyle='--', label='LSL')
plt.title("Original Left-Skewed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()

# Reflected data
plt.subplot(1, 2, 2)
plt.hist(reflected_data, bins=30, color='lightcoral', edgecolor='black', alpha=0.7)
plt.axvline(USL_new, color='red', linestyle='--', label='Adjusted USL')
plt.axvline(LSL_new, color='green', linestyle='--', label='Adjusted LSL')
plt.title("Reflected Right-Skewed Data")
plt.xlabel("Reflected Value")
plt.ylabel("Frequency")
plt.legend()

plt.tight_layout()
plt.show()

# Print results
print(f"Original Data Mean (μ): {np.mean(data):.2f}, Std Dev (σ): {np.std(data):.2f}")
print(f"Reflected Data Mean (μ): {mean_reflected:.2f}, Std Dev (σ): {std_dev_reflected:.2f}")
print(f"CpK (Upper): {cpk_upper:.2f}")
print(f"CpK (Lower): {cpk_lower:.2f}")
print(f"Final CpK: {cpk:.2f}")
# Out:
# Original Data Mean (μ): 28.57, Std Dev (σ): 15.52
# Reflected Data Mean (μ): 52.77, Std Dev (σ): 15.52
# CpK (Upper): -0.03
# CpK (Lower): 1.32
# Final CpK: -0.03
